# %% [markdown]
# # Early Cardiac Event Prediction PipelineSimulates HRV and trend-based early warning detection using synthetic multi-lead ECG data.

# %%
from data_generator import build_datasetimport pandas as pdbuild_dataset(n_samples=200, event_ratio=0.15, output_path='sample_data/cardiac_dataset.csv')df=pd.read_csv('sample_data/cardiac_dataset.csv')print(df.head())
